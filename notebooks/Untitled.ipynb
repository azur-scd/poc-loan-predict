# %%
import pandas as pd
import bamboolib as bam

# %%
color_discrete_map={0: 'rgb(177, 164, 191)', 1: 'rgb(86, 213, 183)'}

# %%
import pandas as pd
df = pd.read_csv(r'/home/docker/app/data/tous_exemplaires_ready.csv', sep=',', decimal='.')
df = df.loc[df['date_pub'] > 1900]
for column_name in ['date_pub', 'statut_ex', 'bib', 'pret', 'acces', 'acq', 'indice']:
    df[column_name] = df[column_name].astype('category')
df
# Out:
#       date_pub statut_ex   bib pret  diff_datecreation_datepub     acces  \
# 0         2001        19   SJA    1                         16    direct
# 1         2005        19  LASH    1                         13    direct
# 2         2007        19  LASH    0                         10    direct
# 3         2007        19   SJA    0                         13    direct
# 4         1942        19  LASH    1                         74  indirect
# ...        ...       ...   ...  ...                        ...       ...
# 54458     2006        19   SJA    1                         12    direct
# 54459     2006        19   SJA    1                         12    direct
# 54460     2007        19   SJA    1                          9    direct
# 54461     2005        19  LASH    0                         16    direct
# 54462     1983        19  LASH    1                         33    direct
#
#          acq  indice
# 0      achat      33
# 1        don     868
# 2      achat      19
# ...

# %%
d=pd.crosstab(columns=["acces,pret"])
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/1555802095.py in <module>
# ----> 1 d=pd.crosstab(columns=["acces,pret"])
#       2 d
#
# TypeError: crosstab() missing 1 required positional argument: 'index'
